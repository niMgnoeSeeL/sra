# %%
# reload modules
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os

# os.chdir("") # set the root directory of the project
import numpy as np
import pandas as pd
from sra.dataloader import (
    get_covs_runs,
    get_run_paths,
    get_trial_paths,
    get_covs_trial,
)
from sra.cfggen import parse_ll, parse_dotfiles, gen_cfg_inter
from sra.mapper import get_bbs_fuzz, get_mapping, fuzzdat_to_obs
from sra.estimator import Graph
from sra.estimator_chunk import structure_estimation

# %%
def get_statistics(num_arr: np.ndarray):
    mean_val = np.mean(num_arr)
    std_val = np.std(num_arr)
    min_val = np.min(num_arr)
    max_val = np.max(num_arr)
    quantiles = pd.DataFrame(num_arr).quantile(
        [0.01] + [1 / 20 * i for i in range(1, 20)] + [0.99]
    )
    print(f"mean: {mean_val}, std: {std_val}, min: {min_val}, max: {max_val}")
    print(f"quantiles:\n{quantiles}")

# %%
import threading

from functools import wraps
import errno
import os
import signal


class TimeoutError(Exception):
    pass


def timeout(seconds=10, error_message=os.strerror(errno.ETIME)):
    def decorator(func):
        def _handle_timeout(signum, frame):
            raise TimeoutError(error_message)

        def wrapper(*args, **kwargs):
            signal.signal(signal.SIGALRM, _handle_timeout)
            signal.alarm(seconds)
            try:
                result = func(*args, **kwargs)
            finally:
                signal.alarm(0)
            return result

        return wraps(func)(wrapper)

    return decorator


@timeout(5)
def print_result(observable_nodes, graph, target_node):
    print(
        f"{target_node}: {structure_estimation(np.zeros((1, len(observable_nodes))),graph,target_node,observable_nodes,2)}"
    )

# %% [markdown]
# # Tcas

# %%
dotfiles = [
    fname
    for fname in os.listdir("fuzz-data/ft_data/source_code/tcas")
    if fname.startswith(".") and fname.endswith(".dot")
]
functions = sorted([fname.split(".")[1] for fname in dotfiles])

bbs_fuzz_path = "fuzz-data/tcas_exp_1/tcas_01/tcas_aflpp_run_01/ft_tcas.json"
bbs_fuzz = get_bbs_fuzz(bbs_fuzz_path)

debug_info_dict, blocks_dict = parse_ll("fuzz-data/ft_data/source_code/tcas/tcas.ll")
cfgs_intra, node_to_bb = parse_dotfiles(
    dotfiles,
    "fuzz-data/ft_data/source_code/tcas",
    debug_info_dict,
    blocks_dict,
    non_overlap_lineidx=False,
)

cfg_inter = gen_cfg_inter(cfgs_intra)
graph = Graph(cfg_inter)

map_fuzz_to_obs_node, map_obs_to_fuzz_node = get_mapping(
    functions, bbs_fuzz, node_to_bb, cfg_inter, debug=True
)
# Out:
# [ALIM]
# bb_fuzz_idxs=       1 node_obs=Node0x11de3a780      ('ALIM', 0)                         obs_node_lines={59, 61} vs fuzz_node_lines=[61]
#
# [Inhibit_Biased_Climb]
# bb_fuzz_idxs=       2 node_obs=Node0x11de3af90      ('Inhibit_Biased_Climb', 0)         obs_node_lines={64, 66} vs fuzz_node_lines=[66]
# bb_fuzz_idxs=       3 node_obs=Node0x11de3b1f0      ('Inhibit_Biased_Climb', 1)         obs_node_lines={66} vs fuzz_node_lines=[66]
# bb_fuzz_idxs=       4 node_obs=Node0x11de3b270      ('Inhibit_Biased_Climb', 2)         obs_node_lines={66} vs fuzz_node_lines=[66]
# bb_fuzz_idxs=       5 node_obs=Node0x11de3b6e0      ('Inhibit_Biased_Climb', 3)         obs_node_lines={66} vs fuzz_node_lines=[66]
#
# [Non_Crossing_Biased_Climb]
# bb_fuzz_idxs=       6 node_obs=Node0x11de3bd40-0    ('Non_Crossing_Biased_Climb', 0)    obs_node_lines={69, 71, 72, 73, 75} vs fuzz_node_lines=[71, 72, 73, 75, 76]
# bb_fuzz_idxs=       6 node_obs=Node0x11de3bd40-1    ('Non_Crossing_Biased_Climb', 0)    obs_node_lines={75, 76} vs fuzz_node_lines=[71, 72, 73, 75, 76]
# bb_fuzz_idxs=       7 node_obs=Node0x11de3d080-0    ('Non_Crossing_Biased_Climb', 1)    obs_node_lines={78} vs fuzz_node_lines=[78]
# bb_fuzz_idxs=       7 node_obs=Node0x11de3d080-1    ('Non_Crossing_Biased_Climb', 1)    obs_node_lines={78} vs fuzz_node_lines=[78]
# bb_fuzz_idxs=       8 node_obs=Node0x11de3ddc0-0    ('Non_Crossing_Biased_Climb', 2)    obs_node_lines={78} vs fuzz_node_lines=[78]
# bb_fuzz_idxs=       8 node_obs=Node0x11de3ddc0-1    ('Non_Crossing_Biased_Climb', 2)    obs_node_lines={78} vs fuzz_node_lines=[78]
# bb_fuzz_idxs=       9 node_obs=Node0x11de3e290-0    ('Non_Crossing_Biased_Climb', 3)    obs_node_lines={78} vs fuzz_node_lines=[78]
# bb_fuzz_idxs=       9 node_obs=Node0x11de3e290-1    ('Non_Crossing_Biased_Climb', 3)    obs_node_lines={78} vs fuzz_node_lines=[78]
# bb_fuzz_idxs=      10 node_obs=Node0x11de3e310      ('Non_Crossing_Biased_Climb', 4)    obs_node_lines={0, 78} vs fuzz_node_lines=[78]
# bb_fuzz_idxs=      11 node_obs=Node0x11de3de40      ('Non_Crossing_Biased_Climb', 5)    obs_node_lines={78, 79} vs fuzz_node_lines=[78, 79]
# bb_fuzz_idxs=      12 node_obs=Node0x11de3d8a0-0    ('Non_Crossing_Biased_Climb', 6)    obs_node_lines={82} vs fuzz_node_lines=[82]
# bb_fuzz_idxs=      12 node_obs=Node0x11de3d8a0-1    ('Non_Crossing_Biased_Climb', 6)    obs_node_lines={82} vs fuzz_node_lines=[82]
# bb_fuzz_idxs=      13 node_obs=Node0x11de3f600      ('Non_Crossing_Biased_Climb', 7)    obs_node_lines={82} vs fuzz_node_lines=[82]
# bb_fuzz_idxs=      14 node_obs=Node0x11de3fbd0-0    ('Non_Crossing_Biased_Climb', 8)    obs_node_lines={82} vs fuzz_node_lines=[82]
# bb_fuzz_idxs=      14 node_obs=Node0x11de3fbd0-1    ('Non_Crossing_Biased_Climb', 8)    obs_node_lines={82} vs fuzz_node_lines=[82]
# bb_fuzz_idxs=      15 node_obs=Node0x11de3f680      ('Non_Crossing_Biased_Climb', 9)    obs_node_lines={0, 82} vs fuzz_node_lines=[82]
# bb_fuzz_idxs=      16 node_obs=Node0x11de3f120      ('Non_Crossing_Biased_Climb', 10)   obs_node_lines={84} vs fuzz_node_lines=[84]
#
# [Non_Crossing_Biased_Descend]
# bb_fuzz_idxs=      19 node_obs=Node0x11de388c0-0    ('Non_Crossing_Biased_Descend', 0)  obs_node_lines={87, 89, 90, 91, 93} vs fuzz_node_lines=[89, 90, 91, 93, 94]
# bb_fuzz_idxs=      19 node_obs=Node0x11de388c0-1    ('Non_Crossing_Biased_Descend', 0)  obs_node_lines={93, 94} vs fuzz_node_lines=[89, 90, 91, 93, 94]
# bb_fuzz_idxs=      20 node_obs=Node0x11de41d90-0    ('Non_Crossing_Biased_Descend', 1)  obs_node_lines={96} vs fuzz_node_lines=[96]
# bb_fuzz_idxs=      20 node_obs=Node0x11de41d90-1    ('Non_Crossing_Biased_Descend', 1)  obs_node_lines={96} vs fuzz_node_lines=[96]
# bb_fuzz_idxs=      21 node_obs=Node0x11de42a00      ('Non_Crossing_Biased_Descend', 2)  obs_node_lines={96} vs fuzz_node_lines=[96]
# bb_fuzz_idxs=      22 node_obs=Node0x11de42fa0-0    ('Non_Crossing_Biased_Descend', 3)  obs_node_lines={96} vs fuzz_node_lines=[96]
# bb_fuzz_idxs=      22 node_obs=Node0x11de42fa0-1    ('Non_Crossing_Biased_Descend', 3)  obs_node_lines={96} vs fuzz_node_lines=[96]
# bb_fuzz_idxs=      23 node_obs=Node0x11de42a80      ('Non_Crossing_Biased_Descend', 4)  obs_node_lines={0, 97, 96} vs fuzz_node_lines=[96, 97]
# bb_fuzz_idxs=      24 node_obs=Node0x11de425b0-0    ('Non_Crossing_Biased_Descend', 5)  obs_node_lines={100} vs fuzz_node_lines=[100]
# bb_fuzz_idxs=      24 node_obs=Node0x11de425b0-1    ('Non_Crossing_Biased_Descend', 5)  obs_node_lines={100} vs fuzz_node_lines=[100]
# bb_fuzz_idxs=      25 node_obs=Node0x11de43f30-0    ('Non_Crossing_Biased_Descend', 6)  obs_node_lines={100} vs fuzz_node_lines=[100]
# bb_fuzz_idxs=      25 node_obs=Node0x11de43f30-1    ('Non_Crossing_Biased_Descend', 6)  obs_node_lines={100} vs fuzz_node_lines=[100]
# bb_fuzz_idxs=      26 node_obs=Node0x11de44400-0    ('Non_Crossing_Biased_Descend', 7)  obs_node_lines={100} vs fuzz_node_lines=[100]
# bb_fuzz_idxs=      26 node_obs=Node0x11de44400-1    ('Non_Crossing_Biased_Descend', 7)  obs_node_lines={100} vs fuzz_node_lines=[100]
# bb_fuzz_idxs=      27 node_obs=Node0x11de44480      ('Non_Crossing_Biased_Descend', 8)  obs_node_lines={0, 100} vs fuzz_node_lines=[100]
# bb_fuzz_idxs=      28 node_obs=Node0x11de43fb0      ('Non_Crossing_Biased_Descend', 9)  obs_node_lines={100} vs fuzz_node_lines=[100]
# bb_fuzz_idxs=      29 node_obs=Node0x11de43b20      ('Non_Crossing_Biased_Descend', 10) obs_node_lines={102} vs fuzz_node_lines=[102]
#
# [Own_Above_Threat]
# bb_fuzz_idxs=      18 node_obs=Node0x11de45bc0      ('Own_Above_Threat', 0)             obs_node_lines={112, 110} vs fuzz_node_lines=[112]
#
# [Own_Below_Threat]
# bb_fuzz_idxs=      17 node_obs=Node0x11de44ce0      ('Own_Below_Threat', 0)             obs_node_lines={105, 107} vs fuzz_node_lines=[107]
#
# [alt_sep_test]
# bb_fuzz_idxs=      30 node_obs=Node0x11de46470      ('alt_sep_test', 0)                 obs_node_lines={115, 117, 118, 119, 121} vs fuzz_node_lines=[117, 118, 119, 121]
# bb_fuzz_idxs=      31 node_obs=Node0x11de466b0      ('alt_sep_test', 1)                 obs_node_lines={121} vs fuzz_node_lines=[121]
# bb_fuzz_idxs=      32 node_obs=Node0x11de48880      ('alt_sep_test', 2)                 obs_node_lines={121} vs fuzz_node_lines=[121]
# bb_fuzz_idxs=      33 node_obs=Node0x11de48330      ('alt_sep_test', 3)                 obs_node_lines={0, 121, 122, 123} vs fuzz_node_lines=[121, 122, 123]
# bb_fuzz_idxs=      34 node_obs=Node0x11de49950      ('alt_sep_test', 4)                 obs_node_lines={123} vs fuzz_node_lines=[123]
# bb_fuzz_idxs=      35 node_obs=Node0x11de499d0      ('alt_sep_test', 5)                 obs_node_lines={0, 123, 125, 127} vs fuzz_node_lines=[123, 125, 127]
# bb_fuzz_idxs=      36 node_obs=Node0x11de4a550      ('alt_sep_test', 6)                 obs_node_lines={127} vs fuzz_node_lines=[127]
# bb_fuzz_idxs=      37 node_obs=Node0x11de49030      ('alt_sep_test', 7)                 obs_node_lines={127} vs fuzz_node_lines=[127]
# bb_fuzz_idxs=      38 node_obs=Node0x11de4ab50      ('alt_sep_test', 8)                 obs_node_lines={127} vs fuzz_node_lines=[127]
# bb_fuzz_idxs=      39 node_obs=Node0x11de4af50-0    ('alt_sep_test', 9)                 obs_node_lines={129} vs fuzz_node_lines=[129]
# bb_fuzz_idxs=      39 node_obs=Node0x11de4af50-1    ('alt_sep_test', 9)                 obs_node_lines={129} vs fuzz_node_lines=[129]
# bb_fuzz_idxs=      40 node_obs=Node0x11de4b720-0    ('alt_sep_test', 10)                obs_node_lines={129} vs fuzz_node_lines=[129]
# bb_fuzz_idxs=      40 node_obs=Node0x11de4b720-1    ('alt_sep_test', 10)                obs_node_lines={129} vs fuzz_node_lines=[129]
# bb_fuzz_idxs=      41 node_obs=Node0x11de4b7a0-0    ('alt_sep_test', 11)                obs_node_lines={0, 129, 130} vs fuzz_node_lines=[129, 130]
# bb_fuzz_idxs=      41 node_obs=Node0x11de4b7a0-1    ('alt_sep_test', 11)                obs_node_lines={130} vs fuzz_node_lines=[129, 130]
# bb_fuzz_idxs=      42 node_obs=Node0x11de4c220-0    ('alt_sep_test', 12)                obs_node_lines={130} vs fuzz_node_lines=[130]
# bb_fuzz_idxs=      42 node_obs=Node0x11de4c220-1    ('alt_sep_test', 12)                obs_node_lines={130} vs fuzz_node_lines=[130]
# bb_fuzz_idxs=      43 node_obs=Node0x11de4c2a0      ('alt_sep_test', 13)                obs_node_lines={0, 130, 131} vs fuzz_node_lines=[130, 131]
# bb_fuzz_idxs=      44 node_obs=Node0x11de4cbb0      ('alt_sep_test', 14)                obs_node_lines={131} vs fuzz_node_lines=[131]
# bb_fuzz_idxs=      45 node_obs=Node0x11de4d030      ('alt_sep_test', 15)                obs_node_lines={135} vs fuzz_node_lines=[135]
# bb_fuzz_idxs=      46 node_obs=Node0x11de4cc30      ('alt_sep_test', 16)                obs_node_lines={136} vs fuzz_node_lines=[136]
# bb_fuzz_idxs=      47 node_obs=Node0x11de4a9d0      ('alt_sep_test', 17)                obs_node_lines={137} vs fuzz_node_lines=[137]
# bb_fuzz_idxs=      48 node_obs=Node0x11de4aa50      ('alt_sep_test', 18)                obs_node_lines={138} vs fuzz_node_lines=[138]
# bb_fuzz_idxs=      49 node_obs=Node0x11de4dd80      ('alt_sep_test', 19)                obs_node_lines={139} vs fuzz_node_lines=[139]
# bb_fuzz_idxs=      50 node_obs=Node0x11de4de00      ('alt_sep_test', 20)                obs_node_lines={141} vs fuzz_node_lines=[141]
# bb_fuzz_idxs=      -1 node_obs=Node0x11de4e1d0      ('alt_sep_test', 21)                obs_node_lines=None
# bb_fuzz_idxs=      -1 node_obs=Node0x11de4d9c0      ('alt_sep_test', 22)                obs_node_lines=None
# bb_fuzz_idxs=      51 node_obs=Node0x11de4d3d0      ('alt_sep_test', 23)                obs_node_lines={142} vs fuzz_node_lines=[142]
# bb_fuzz_idxs=      52 node_obs=Node0x11de4a5d0      ('alt_sep_test', 24)                obs_node_lines={144} vs fuzz_node_lines=[144]
#
# [initialize]
# bb_fuzz_idxs=       0 node_obs=Node0x11de39810      ('initialize', 0)                   obs_node_lines={51, 53, 54, 55, 56, 57} vs fuzz_node_lines=[53, 54, 55, 56, 57]
#
# [main]
# bb_fuzz_idxs=      53 node_obs=Node0x11de4ec80      ('main', 0)                         obs_node_lines={147, 148, 151} vs fuzz_node_lines=[147, 148, 151]
# bb_fuzz_idxs=      54 node_obs=Node0x11de4fdc0      ('main', 1)                         obs_node_lines={153, 154} vs fuzz_node_lines=[153, 154]
# bb_fuzz_idxs=      55 node_obs=Node0x11de4fe40      ('main', 2)                         obs_node_lines={157, 159} vs fuzz_node_lines=[157, 159]
# bb_fuzz_idxs=      56 node_obs=Node0x11de514f0      ('main', 3)                         obs_node_lines={160, 161} vs fuzz_node_lines=[160, 161]
# bb_fuzz_idxs=      57 node_obs=Node0x11de51570      ('main', 4)                         obs_node_lines={164, 166, 168, 170, 172} vs fuzz_node_lines=[164, 166, 168, 170, 172]
# bb_fuzz_idxs=      58 node_obs=Node0x11de53be0      ('main', 5)                         obs_node_lines={172} vs fuzz_node_lines=[172]
# bb_fuzz_idxs=      59 node_obs=Node0x11de54200      ('main', 6)                         obs_node_lines={174, 175} vs fuzz_node_lines=[174, 175]
# bb_fuzz_idxs=      60 node_obs=Node0x11de55940      ('main', 7)                         obs_node_lines={172} vs fuzz_node_lines=[172]
# bb_fuzz_idxs=      61 node_obs=Node0x11de54280-0    ('main', 8)                         obs_node_lines={178} vs fuzz_node_lines=[178, 179, 181, 182, 183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 194, 195]
# bb_fuzz_idxs=      61 node_obs=Node0x11de54280-1    ('main', 8)                         obs_node_lines={192, 194, 179, 181, 182, 183, 184, 185, 186, 187, 188, 189, 190, 191} vs fuzz_node_lines=[178, 179, 181, 182, 183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 194, 195]
# bb_fuzz_idxs=      61 node_obs=Node0x11de54280-2    ('main', 8)                         obs_node_lines={194, 195} vs fuzz_node_lines=[178, 179, 181, 182, 183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 194, 195]

# %%
projname = "tcas"
runs_path = "fuzz-data/tcas_exp_1"
run_paths = get_run_paths(runs_path, projname)
covs_trials_f = []
for run_path in run_paths:
    for trial_path in get_trial_paths(run_path):
        covs_trial = get_covs_trial(trial_path)
        covs = [cov for cov in covs_trial if max(cov) > 0]
        covs_trials_f.append(covs)
print(f"number of trials: {len(covs_trials_f)}")
# Out:
# number of trials: 990

# %%
covs_f = []
for covs in covs_trials_f:
    covs_f.extend(covs)
covs_f = np.array(covs_f)
print(f"{covs_f.shape=}")
cov_maxs = np.max(covs_f, axis=1)
print(f"{cov_maxs.shape=}")
get_statistics(cov_maxs)
# Out:
# covs_f.shape=(357377, 63)
# cov_maxs.shape=(357377,)
# mean: 226.89232659068713, std: 153.19242703306415, min: 4, max: 1132
# quantiles:
#           0
# 0.01   79.0
# 0.05   90.0
# 0.10   92.0
# 0.15   99.0
# 0.20  108.0
# 0.25  111.0
# 0.30  123.0
# 0.35  125.0
# 0.40  140.0
# 0.45  143.0
# 0.50  165.0
# 0.55  170.0
# 0.60  199.0
# 0.65  232.0
# 0.70  248.0
# 0.75  320.0
# 0.80  336.0
# 0.85  428.0
# 0.90  453.0
# 0.95  580.0
# 0.99  640.0

# %%
in_between_range = [90 <= cov_max_f <= 580 for cov_max_f in cov_maxs]
cov_data_f = covs_f[in_between_range]
print(f"{cov_data_f.shape=}")
sum_data_f = np.sum(cov_data_f, axis=0)
print(f"{sum_data_f.shape=}")
min_obs = np.min(sum_data_f[sum_data_f > 0])
print(f"{min_obs=}")
num_obss = cov_maxs[in_between_range]
total_obs = np.sum(num_obss)
print(f"{total_obs=}")
# Out:
# cov_data_f.shape=(325346, 63)
# sum_data_f.shape=(63,)
# min_obs=2442916
# total_obs=68911068

# %%
nodenames = list(cfg_inter["nodes"].keys())
cov_data_o = fuzzdat_to_obs(
    cov_data_f, cfg_inter, bbs_fuzz, map_fuzz_to_obs_node, nodenames
)
print(f"{cov_data_o.shape=}")
sum_data_o = np.sum(cov_data_o, axis=0)
print(f"{sum_data_o.shape=}")
# Out:
# cov_data_o.shape=(325346, 152)
# sum_data_o.shape=(152,)

# %%
def order_found(
    covs: np.ndarray, observable_ids_f, consider_remaining: bool = True
):
    founded = set()
    ret = {idx: np.nan for idx in range(len(covs[0]))}
    last_found = {}
    for cov in covs:
        found = {idx for idx in range(len(cov)) if cov[idx] > 0}
        new_found = found - founded
        founded = founded | found
        for idx in new_found:
            ret[idx] = len(founded)
        if len(new_found):
            last_found = new_found
    if consider_remaining:
        remaining = observable_ids_f - founded
        if len(remaining):
            founded = founded | remaining
            for idx in remaining:
                ret[idx] = len(founded)
            last_found = remaining
    return ret, last_found

# %%
observable_ids_f = {i for i in range(len(sum_data_f)) if sum_data_f[i] > 0}


order_data = {idx: [] for idx in range(len(covs_trials_f[0][0]))}
last_found_cnt = {}
for covs_trial in covs_trials_f:
    order_trial, last_found = order_found(
        covs_trial, observable_ids_f, consider_remaining=False
    )
    for idx in order_trial:
        if np.isnan(order_trial[idx]):
            continue
        order_data[idx].append(order_trial[idx])
    for idx in last_found:
        if idx not in last_found_cnt:
            last_found_cnt[idx] = 0
        last_found_cnt[idx] += 1
for idx, orders in order_data.items():
    if idx <= 10:
        print(f"{idx}: {np.nanmean(orders):.2f} ({orders[:5]}...)")
    order_data[idx] = np.nanmean(order_data[idx])
    if np.isnan(order_data[idx]):
        order_data[idx] = 0

order_df = pd.DataFrame(order_data, index=[0]).T
display(order_df.sort_values(by=0, ascending=False).head(10))

last_found_df = pd.DataFrame(last_found_cnt, index=[0])
display(last_found_df.T.sort_values(by=0, ascending=False).head(10))
# Out:
# 0: 25.85 ([37, 37, 14, 36, 12]...)
# 1: 48.76 ([49, 49, 44, 52, 57]...)
# 2: 44.12 ([37, 37, 44, 36, 44]...)
# 3: 49.83 ([49, 37, 44, 52, 44]...)
# 4: 44.30 ([37, 49, 44, 36, 44]...)
# 5: 44.12 ([37, 37, 44, 36, 44]...)
# 6: 44.12 ([37, 37, 44, 36, 44]...)
# 7: 50.52 ([49, 49, 50, 52, 44]...)
# 8: 55.78 ([49, 49, 55, 52, 57]...)
# 9: 55.78 ([49, 49, 55, 52, 57]...)
# 10: 55.78 ([49, 49, 55, 52, 57]...)
# /var/folders/v9/wc5dh1fd691947y71hyt_2280000gn/T/ipykernel_89942/3872303765.py:21: RuntimeWarning: Mean of empty slice
#   order_data[idx] = np.nanmean(order_data[idx])
#             0
# 37  58.711066
# 47  57.471717
# 44  57.471717
# 22  55.782828
# 21  55.782828
# 8   55.782828
# 9   55.782828
# 10  55.782828
# 49  55.250505
# 11  50.520202
#       0
# 37  894
# 44   65
# 47   65
# 49   36
# 8     8
# 9     8
# 10    8
# 21    8
# 22    8

# %%
ids_of_interest_f = [37]
for idx_f in ids_of_interest_f:
    print(
        f"map_fuzz_to_obs_node[{idx_f}]={map_fuzz_to_obs_node[idx_f]}"
    )
# Out:
# map_fuzz_to_obs_node[37]={'Node0x11de49030'}

# %% [markdown]
# # Printtokens2

# %%
source_dir = "fuzz-data/ft_data/source_code/printtokens2_2"
source_name = "printtokens2_2_fuzz"

dotfiles = [
    fname
    for fname in os.listdir(source_dir)
    if fname.startswith(".") and fname.endswith(".dot")
]
functions = sorted([fname.split(".")[1] for fname in dotfiles])

bbs_fuzz_path = "fuzz-data/printtokens2_2_exp_1/printtokens2_2_01/printtokens2_2_aflpp_run_01/ft_printtokens2_2.json"
bbs_fuzz = get_bbs_fuzz(bbs_fuzz_path)

debug_info_dict, blocks_dict = parse_ll(
    os.path.join(source_dir, f"{source_name}.ll")
)
cfgs_intra, node_to_bb = parse_dotfiles(
    dotfiles,
    source_dir,
    debug_info_dict,
    blocks_dict,
    non_overlap_lineidx=False,
)

cfg_inter = gen_cfg_inter(cfgs_intra)
graph = Graph(cfg_inter)

map_fuzz_to_obs_node, map_obs_to_fuzz_node = get_mapping(
    functions, bbs_fuzz, node_to_bb, cfg_inter, debug=True
)

# %%
projname = "printtokens2_2"
runs_path = "fuzz-data/printtokens2_2_exp_1"
run_paths = get_run_paths(runs_path, projname)
covs_trials_f = []
for run_path in run_paths:
    for trial_path in get_trial_paths(run_path):
        covs_trial = get_covs_trial(trial_path)
        covs = [cov for cov in covs_trial if max(cov) > 0]
        covs_trials_f.append(covs)
print(f"number of trials: {len(covs_trials_f)}")

# %%
covs_f = []
for covs in covs_trials_f:
    covs_f.extend(covs)
covs_f = np.array(covs_f)
print(f"{covs_f.shape=}")
cov_maxs = np.max(covs_f, axis=1)
print(f"{cov_maxs.shape=}")
get_statistics(cov_maxs)

# %%
in_between_range = [89 <= cov_max_f <= 563 for cov_max_f in cov_maxs]
cov_data_f = covs_f[in_between_range]
print(f"{cov_data_f.shape=}")
sum_data_f = np.sum(cov_data_f, axis=0)
print(f"{sum_data_f.shape=}")
min_obs = np.min(sum_data_f[sum_data_f > 0])
print(f"{min_obs=}")
num_obss = cov_maxs[in_between_range]
total_obs = np.sum(num_obss)
print(f"{total_obs=}")

# %%
nodenames = list(cfg_inter["nodes"].keys())
cov_data_o = fuzzdat_to_obs(
    cov_data_f, cfg_inter, bbs_fuzz, map_fuzz_to_obs_node, nodenames
)
print(f"{cov_data_o.shape=}")
sum_data_o = np.sum(cov_data_o, axis=0)
print(f"{sum_data_o.shape=}")

# %%
order_data = {idx: [] for idx in range(len(covs_trials_f[0][0]))}
last_found_cnt = {}
for covs_trial in covs_trials_f:
    order_trial, last_found = order_found(covs_trial, observable_ids_f, consider_remaining=False)
    for idx in order_trial:
        if np.isnan(order_trial[idx]):
            continue
        order_data[idx].append(order_trial[idx])
    for idx in last_found:
        if idx not in last_found_cnt:
            last_found_cnt[idx] = 0
        last_found_cnt[idx] += 1
for idx, orders in order_data.items():
    if idx <= 10:
        print(f"{idx}: {np.nanmean(orders):.2f} ({orders[:5]}...)")
    order_data[idx] = np.nanmean(order_data[idx])
    if np.isnan(order_data[idx]):
        order_data[idx] = 0

order_df = pd.DataFrame(order_data, index=[0]).T
display(order_df.sort_values(by=0, ascending=False).head(10))

last_found_df = pd.DataFrame(last_found_cnt, index=[0])
display(last_found_df.T.sort_values(by=0, ascending=False).head(10))

# %%
ids_of_interest_f = [118, 95]
for idx_f in ids_of_interest_f:
    print(
        f"map_fuzz_to_obs_node[{idx_f}]={map_fuzz_to_obs_node[idx_f]}"
    )

# %% [markdown]
# # Replace

# %%
source_dir = "fuzz-data/ft_data/source_code/replace"
source_name = "replace_fuzz"

dotfiles = [
    fname
    for fname in os.listdir(source_dir)
    if fname.startswith(".") and fname.endswith(".dot")
]
functions = sorted([fname.split(".")[1] for fname in dotfiles])

bbs_fuzz_path = "fuzz-data/replace_exp_2/replace_01/replace_aflpp_run_01/ft_replace.json"
bbs_fuzz = get_bbs_fuzz(bbs_fuzz_path)

debug_info_dict, blocks_dict = parse_ll(
    os.path.join(source_dir, f"{source_name}.ll")
)
cfgs_intra, node_to_bb = parse_dotfiles(
    dotfiles,
    source_dir,
    debug_info_dict,
    blocks_dict,
    non_overlap_lineidx=False,
)

cfg_inter = gen_cfg_inter(cfgs_intra)
graph = Graph(cfg_inter)

map_fuzz_to_obs_node, map_obs_to_fuzz_node = get_mapping(
    functions, bbs_fuzz, node_to_bb, cfg_inter, debug=True
)

# %%
projname = "replace"
runs_path = "fuzz-data/replace_exp_2"
run_paths = get_run_paths(runs_path, projname)
covs_trials_f = []
for run_path in run_paths:
    for trial_path in get_trial_paths(run_path):
        covs_trial = get_covs_trial(trial_path)
        covs = [cov for cov in covs_trial if max(cov) > 0]
        covs_trials_f.append(covs)
print(f"number of trials: {len(covs_trials_f)}")

# %%
covs_f = []
for covs in covs_trials_f:
    covs_f.extend(covs)
covs_f = np.array(covs_f)
print(f"{covs_f.shape=}")
cov_maxs = np.max(covs_f, axis=1)
print(f"{cov_maxs.shape=}")
get_statistics(cov_maxs)

# %%
in_between_range = [90.0 <= cov_max_f <= 609.0 for cov_max_f in cov_maxs]
cov_data_f = covs_f[in_between_range]
print(f"{cov_data_f.shape=}")
sum_data_f = np.sum(cov_data_f, axis=0)
print(f"{sum_data_f.shape=}")
min_obs = np.min(sum_data_f[sum_data_f > 0])
print(f"{min_obs=}")
num_obss = cov_maxs[in_between_range]
total_obs = np.sum(num_obss)
print(f"{total_obs=}")

# %%
nodenames = list(cfg_inter["nodes"].keys())
cov_data_o = fuzzdat_to_obs(
    cov_data_f, cfg_inter, bbs_fuzz, map_fuzz_to_obs_node, nodenames
)
print(f"{cov_data_o.shape=}")
sum_data_o = np.sum(cov_data_o, axis=0)
print(f"{sum_data_o.shape=}")

# %%
observable_ids_f = {i for i in range(len(sum_data_f)) if sum_data_f[i] > 0}

order_data = {idx: [] for idx in range(len(covs_trials_f[0][0]))}
last_found_cnt = {}
for covs_trial in covs_trials_f:
    order_trial, last_found = order_found(covs_trial, observable_ids_f, consider_remaining=False)
    for idx in order_trial:
        if np.isnan(order_trial[idx]):
            continue
        order_data[idx].append(order_trial[idx])
    for idx in last_found:
        if idx not in last_found_cnt:
            last_found_cnt[idx] = 0
        last_found_cnt[idx] += 1
for idx, orders in order_data.items():
    if idx <= 10:
        print(f"{idx}: {np.nanmean(orders):.2f} ({orders[:5]}...)")
    order_data[idx] = np.nanmean(order_data[idx])
    if np.isnan(order_data[idx]):
        order_data[idx] = 0

order_df = pd.DataFrame(order_data, index=[0]).T
display(order_df.sort_values(by=0, ascending=False).head(10))

last_found_df = pd.DataFrame(last_found_cnt, index=[0])
display(last_found_df.T.sort_values(by=0, ascending=False).head(10))

# %%
ids_of_interest_f = [31, 32, 29, 30, 33, 28, 12, 10, 23, 24]
for idx_f in ids_of_interest_f:
    print(
        f"map_fuzz_to_obs_node[{idx_f}]={map_fuzz_to_obs_node[idx_f]}"
    )
